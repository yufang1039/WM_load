# %%
from mutagen.mp3 import MP3

# Path to your MP3 file
file_path = '/Users/yufang/WM_load/chinese_audio_output/four_3_syllable_words/_syllable_cache/介.mp3'

# Load the MP3 file
audio = MP3(file_path)

# Print duration in seconds
print(f"Duration: {audio.info.length:.2f} seconds")
# Out:
# Duration: 0.43 seconds
